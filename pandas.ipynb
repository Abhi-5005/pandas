# %%
import pandas as pd

# %%
df = pd.read_csv("sample.csv")

# %%
df
# Out:
#    ID    Name  Price
# 0   1  Item A    100
# 1   2  Item B    200
# 2   3  Item C    300

# %%
print(df.to_dict())
# Out:
# {'ID': {0: 1, 1: 2, 2: 3}, 'Name': {0: 'Item A', 1: 'Item B', 2: 'Item C'}, 'Price': {0: 100, 1: 200, 2: 300}}

# %%
ele = {
    "cars":["BMW","volvo","honda"],
    "passing":[1,2,3]
}

# %%
ele
# Out:
# {'cars': ['BMW', 'volvo', 'honda'], 'passing': [1, 2, 3]}

# %%
df = pd.DataFrame(ele)

# %%
df
# Out:
#     cars  passing
# 0    BMW        1
# 1  volvo        2
# 2  honda        3

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
lis = ["abhi","anshul","ram","shyam"]

# %%
df = pd.Series(lis, index = ["x","y","z","c"])

# %%
df
# Out:
# x      abhi
# y    anshul
# z       ram
# c     shyam
# dtype: object

# %%
print(df[0])
# Out:
# abhi
# C:\Users\ABHISHEK\AppData\Local\Temp\ipykernel_11932\1138601271.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[0])

# %%
dis = {
    "day1":[1,2,4,5,56],
    "day2":[3,46,7,5,7]

}

# %%
df = pd.DataFrame(dis, index = ["x","y","z","b","c"])

# %%
df
# Out:
#    day1  day2
# x     1     3
# y     2    46
# z     4     7
# b     5     5
# c    56     7

# %%
print(df.loc["x"])
# Out:
# day1    1
# day2    3
# Name: x, dtype: int64

# %%
df.loc[0]
# Out:
# day1    1
# day2    3
# Name: 0, dtype: int64

# %%
df.loc[1]
# Out:
# day1     2
# day2    46
# Name: 1, dtype: int64

# %%
df
# Out:
#    day1  day2
# 0     1     3
# 1     2    46
# 2     4     7
# 3     5     5
# 4    56     7

# %%
df.iloc[0:5]
# Out:
#    day1  day2
# 0     1     3
# 1     2    46
# 2     4     7
# 3     5     5
# 4    56     7

# %%
df.loc[1]
# Out:
# day1     2
# day2    46
# Name: 1, dtype: int64

# %%
df = pd.read_csv("sample.csv")

# %%
df
# Out:
#    ID    Name  Price
# 0   1  Item A    100
# 1   2  Item B    200
# 2   3  Item C    300

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
pd.options.display.max_rows = 170

# %%
pd.options.display.max_rows
# Out:
# 170

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_json("file.json")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

# %%
data
# Out:
# {'Duration': {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60},
#  'Pulse': {'0': 110, '1': 117, '2': 103, '3': 109, '4': 117, '5': 102},
#  'Maxpulse': {'0': 130, '1': 145, '2': 135, '3': 175, '4': 148, '5': 127},
#  'Calories': {'0': 409, '1': 479, '2': 340, '3': 282, '4': 406, '5': 300}}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df.head(2)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479

# %%
df.tail(2)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes

# %%
# list to list

# %%
empdata = [[101,'A',564534],[102,'B',34343434],[103,'C',535353]]

# %%
empdata
# Out:
# [[101, 'A', 564534], [102, 'B', 34343434], [103, 'C', 535353]]

# %%
df = pd.DataFrame(empdata)

# %%
df
# Out:
#      0  1         2
# 0  101  A    564534
# 1  102  B  34343434
# 2  103  C    535353

# %%
lis = [1,2,34,54,6,67,8]

# %%
df = pd.DataFrame(lis)

# %%
df
# Out:
#     0
# 0   1
# 1   2
# 2  34
# 3  54
# 4   6
# 5  67
# 6   8

# %%
empdata = ((101,'A',564534),(102,'B',34343434),(103,'C',535353))

# %%
df = pd.DataFrame(empdata)

# %%
df
# Out:
#      0  1         2
# 0  101  A    564534
# 1  102  B  34343434
# 2  103  C    535353

# %%
empdata = {'id':[101,102,103],
           'name':['a','b','c'],
           'city':['p','q','s']
          }

# %%
df = pd.DataFrame(empdata)

# %%
df
# Out:
#     id name city
# 0  101    a    p
# 1  102    b    q
# 2  103    c    s

# %%
df = pd.read_excel("FSI-2023-DOWNLOAD.xlsx")

# %%
df
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %%
df.loc[[1,2,5,6]]
# Out:
#        Country  Year Rank  Total  S1: Demographic Pressures  \
# 1        Yemen  2023  2nd  108.9                        9.6
# 2  South Sudan  2023  3rd  108.5                        9.7
# 5  Afghanistan  2023  6th  106.6                        9.2
# 6        Sudan  2023  7th  106.2                        8.8
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 5                    8.6                  8.3
# 6                    9.6                  9.3
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 1                               6.4                      7.9          9.9
# 2                               6.5                      8.6          8.6
# 5                               8.5                      8.2          9.6
# 6                               7.5                      8.5          9.3
#
# ...

# %%
import pandas as pd

df = pd.read_excel("empdata (1).xlsx")

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune>

# %%
df.head(2)
# Out:
#       id    name dept Region
# 0    434  keshav   IT   Pune
# 1  43423  Pratik   HR   Pune

# %%
df.tail(2)
# Out:
#       id    name   dept Region
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df['name']
# Out:
# 0    keshav
# 1    Pratik
# 2    Sonali
# 3      Amit
# Name: name, dtype: object

# %%
df.get('ename','No col with you"r name')
# Out:
# 'No col with you"r name'

# %%
df[['name','id']]
# Out:
#      name     id
# 0  keshav    434
# 1  Pratik  43423
# 2  Sonali  43434
# 3    Amit  32342

# %%
df['id'].astype(float)
# Out:
# 0      434.0
# 1    43423.0
# 2    43434.0
# 3    32342.0
# Name: id, dtype: float64

# %%
df['name']
# Out:
# 0    keshav
# 1    Pratik
# 2    Sonali
# 3      Amit
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'dept', 'Region'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.size
# Out:
# 16

# %%
df.ndim
# Out:
# 2

# %%
lis =[1,2,343,4,6,5]

# %%
dd = pd.Series(lis)

# %%
dd.ndim
# Out:
# 1

# %%
dd
# Out:
# 0      1
# 1      2
# 2    343
# 3      4
# 4      6
# 5      5
# dtype: int64

# %%
df.describe()
# Out:
#                  id
# count      4.000000
# mean   29908.250000
# std    20332.641514
# min      434.000000
# 25%    24365.000000
# 50%    37882.500000
# 75%    43425.750000
# max    43434.000000

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.loc[1:3 , ["name","id"]]
# Out:
#      name     id
# 1  Pratik  43423
# 2  Sonali  43434
# 3    Amit  32342

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.iat[1,1]
# Out:
# 'Pratik'

# %%
df.query('id' == 
         2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9228\2154786525.py in ?()
# ----> 1 df.query('id' ==
#       2          2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, expr, inplace, **kwargs)
#    4816         """
#    4817         inplace = validate_bool_kwarg(inplace, "inplace")
#    4818         if not isinstance(expr, str):
#    4819             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4820             raise ValueError(msg)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
#    4823         res = self.eval(expr, **kwargs)
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df[df["name"].isin(["Pratik"])]
# Out:
#       id    name dept Region
# 1  43423  Pratik   HR   Pune

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.sample(2)
# Out:
#       id    name   dept Region
# 3  32342    Amit     HR   Pune
# 2  43434  Sonali  Admin   Pune

# %%
df["id"] = df["id"]*2

# %%
df
# Out:
#       id    name   dept Region
# 0    868  keshav     IT   Pune
# 2  86868  Sonali  Admin   Pune
# 3  64684    Amit     HR   Pune

# %%
df.drop(1, axis = 0,inplace =True)

# %%
df
# Out:
#       id    name   dept Region
# 0    868  keshav     IT   Pune
# 2  86868  Sonali  Admin   Pune
# 3  64684    Amit     HR   Pune

# %%
df.drop(columns = ["dept","id"])
# Out:
#      name Region
# 0  keshav   Pune
# 2  Sonali   Pune
# 3    Amit   Pune

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.drop
# Out:
# <bound method DataFrame.drop of       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune>

# %%
df.rename({"id":"emp_id"},axis = 1 ,inplace =True)

# %%
df
# Out:
#    emp_id    name   dept Region
# 0     434  keshav     IT   Pune
# 1   43423  Pratik     HR   Pune
# 2   43434  Sonali  Admin   Pune
# 3   32342    Amit     HR   Pune

# %%
col = ['a','b','c','d']

col1 = ['p','q','r']

# %%
tuple(zip(col,col1))
# Out:
# (('a', 'p'), ('b', 'q'), ('c', 'r'))

# %%
df["name"] = None

# %%
df
# Out:
#    emp_id  name   dept Region
# 0     434  None     IT   Pune
# 1   43423  None     HR   Pune
# 2   43434  None  Admin   Pune
# 3   32342  None     HR   Pune

# %%
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df[0]
#
# ...

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.replace("keshav","ram")
# Out:
#       id    name   dept Region
# 0    434     ram     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.replace(["Pratik",None] ,axis =1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 df.replace(["Pratik",None] ,axis =1)
#
# TypeError: NDFrame.replace() got an unexpected keyword argument 'axis'

# %%
df.dropna()
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
df.drop_duplicates()
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune

# %%
dd
# Out:
# 0      1
# 1      2
# 2    343
# 3      4
# 4      6
# 5      5
# dtype: int64

# %%
pd.DataFrame(lis)
# Out:
#      0
# 0    1
# 1    2
# 2  343
# 3    4
# 4    6
# 5    5

# %%
pd.concat([dd,df],axis =1)
# Out:
#      0       id    name   dept Region
# 0    1    434.0  keshav     IT   Pune
# 1    2  43423.0  Pratik     HR   Pune
# 2  343  43434.0  Sonali  Admin   Pune
# 3    4  32342.0    Amit     HR   Pune
# 4    6      NaN     NaN    NaN    NaN
# 5    5      NaN     NaN    NaN    NaN

# %%
import pandas as pd

# %%
df = pd.read_excel("Book 6.xlsx",sheet_name = "Sheet2")

# %%
df
# Out:
#    p_id  dimension
# 0   101        NaN
# 1   103        NaN
# 2   102     1200.0

# %%
ff = pd.read_excel("Book 6.xlsx",sheet_name = "Sheet1")

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN

# %%
for i in range(0,len(ff['cbm'])+1):
    temp = ff['cbm'].iat[i]
    print(temp)
# Out:
# 1000.0
# nan
# nan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 for i in range(0,len(ff['cbm'])+1):
# ----> 2     temp = ff['cbm'].iat[i]
#       3     print(temp)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1234, in Series._get_value(self, label, takeable)
#    1221 """
#    1222 Quickly retrieve single value at passed index label.
#    1223
#    (...)
#    1231 scalar value
#    1232 """
#    1233 if takeable:
# -> 1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
def user():
    for i in range(0,len(ff['cbm'])+1):
        if ff['cbm'].isna.loc(i):
            if (ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i] == 'NaN'):
                ff['new'].loc[i] =df['dimension'].loc(i)

            else:
                temp = ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i]
                ff['new'] = temp
        else:
            ff['new'] = ff['cbm'].loc(i)

# %%
print(ff['cbm'].isna().loc[1])
# Out:
# True

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN

# %%
ff['new'] = user()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11272\3166311691.py in ?()
# ----> 1 ff['new'] = user()
#
# ~\AppData\Local\Temp\ipykernel_11272\3652171792.py in ?()
#       1 def user():
#       2     for i in range(0,len(ff['cbm'])+1):
# ----> 3         if ff['cbm'].loc(i)=='NaN':
#       4             if (ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i] == 'NaN'):
# ...

# %%
ff['cbm'].isna().loc(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11576\3149967852.py in ?()
# ----> 1 ff['cbm'].isna().loc(1)
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#    p_id  dimension
# 0   101        NaN
# 1   103        NaN
# 2   102     1200.0

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN

# %%
def user():
    for i in range(0,3):
        if pd.isna(ff['cbm'].loc[i]):
            if ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i] == 0:
                if pd.isna(df['dimension'].loc[i]):
                    ff['new'] = 0
                else:
                    ff['new'] = df['dimension']
            else:
                temp = ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i]
                ff['new'] = temp
        else:
            ff.loc[i, 'new'] = float(ff.loc[i, 'cbm'])

# %%
user()

# %%
print(temp)
# Out:
# 1000.0

# %%
pd.isna(ff['cbm'].at[1])
# Out:
# True

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm  new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  NaN
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN  NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN  NaN

# %%
temp = float(ff['cbm'].loc[0])

# %% [markdown]
# temp

# %%
temp
# Out:
# 1000.0

# %%
def user():
    j = 0
    for i in ff['cbm']:
        if pd.isna(i):



            
        else:
            ff['new'][j] = i
            j+= 1

# %%
user()
# Out:
# nan
# nan
# C:\Users\ABHISHEK\AppData\Local\Temp\ipykernel_11272\1336663258.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   ff['new'][j] = i
# ...

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm     new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN     NaN

# %%
float(ff['cbm'].loc[1])
# Out:
# nan

# %%
for i in range(0,3):
    temp = float(ff['cbm'].loc[i])
    ff[ff['new'].at[i,temp]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 3
#       1 for i in range(0,3):
#       2     temp = float(ff['cbm'].loc[i])
# ----> 3     ff[ff['new'].at[i,temp]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
# ...

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm  new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  NaN
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN  NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN  NaN

# %%
ff.loc[0, 'new'] = float(ff.loc[i, 'cbm'])

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm     new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN     NaN

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm  new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  NaN
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN  NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN  NaN

# %%
def user():
    for i in range(0,3):
        if pd.isna(ff['cbm'].loc[i]):
            if pd.isna(ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i]):
                if pd.isna(df['dimension'].loc[i]):
                    ff.loc[i,'new'] = 0
                else:
                    ff.loc[i,'new'] = float(df['dimension'].loc[i])
            else:
                ff.loc[i, 'new'] = ff['l'].loc[i] * ff['w'].loc[i] * ff['h'].loc[i]
                
        else:
            ff.loc[i, 'new'] = float(ff.loc[i, 'cbm'])

# %%
user()

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm     new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN  9384.0
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN     0.0

# %%
df.loc[2,'dimension'] = 0

# %%
ff.loc[2,'new']=float(df['dimension'].loc[2])

# %%
df
# Out:
#    p_id  dimension
# 0   101        NaN
# 1   103        NaN
# 2   102        0.0

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm     new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0  1000.0
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN  9384.0
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN  1200.0

# %%
ff
# Out:
#    p_id pn   pp origin destination     l     w     h     cbm     new
# 0   101  c  755    pne          gj  20.0  11.0  23.0  1000.0     NaN
# 1   102  s  565    mum          dl  12.0  34.0  23.0     NaN     NaN
# 2   103  g  456    chl         bng   NaN   NaN   NaN     NaN  1200.0

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'id ': [1,2,3],
    'name ' : ["abhi","ram","shyam"],
    'date': ['01-01-2020','01-01-2020','01-01-2020']
})

# %%
df
# Out:
#    id   name         date
# 0    1   abhi  01-01-2020
# 1    2    ram  01-01-2020
# 2    3  shyam  01-01-2020

# %%
df.dtypes
# Out:
# id        int64
# name     object
# date     object
# dtype: object

# %%
dfpd.to_datetime(df['date'])
# Out:
# 0   2020-01-01
# 1   2020-01-01
# 2   2020-01-01
# Name: date, dtype: datetime64[ns]
